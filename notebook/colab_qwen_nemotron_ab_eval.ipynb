# %% [markdown]
# # Qwen vs NVIDIA Nemotron A100 evaluation
# Runs the repository evaluation script sequentially and saves a JSON report.

# %%
# !nvidia-smi --query-gpu=name,memory.total --format=csv,noheader
# !pip -q install "transformers==5.13.1" accelerate sentencepiece protobuf
# %run /content/colab_qwen_nemotron_ab_eval.py
